# %% [markdown]
# # Project Portfolio of Heart Disease Analytics Using Python, Matplotlib and Seaborn

# %% [markdown]
# # Step 1. Install Required Libraries

# %%
# Install required Libraries to work.
# pip install pandas
# pip install matplotlib
# pip install seaborn --upgrade

# %% [markdown]
# # Step 2. Import Required Libraries

# %%
# Import Libraries into the environment.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Step 3. Import Data Sheet into the environment

# %%
# To import the dataset.
data = pd.read_csv("C:\Data Files\Kaggle Datasets\Heart Disease\heart.csv")

# %% [markdown]
# # Step 4. Display the first five rows of the data

# %%
# To diplay the first 5 rows of the dataset
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
# To display the last 5 rows of the dataset
data.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 723      1   0     2       1
# 733      1   0     2       1
# 739      2   1     3       0
# 843      2   0     2       0
# 878      1   1     3       0

# %% [markdown]
# # Step 5. Display the structure of the data, how many rows and columns in the data set.
# ### The data has 1025 rows and 14 columns

# %%
# To display the structure of the datset.
data.shape
# Out:
# (302, 14)

# %%
print("Number of Rows:", data.shape[0])
print("Number of Columns:", data.shape[1])
# Out:
# Number of Rows: 302
# Number of Columns: 14

# %% [markdown]
# # Step 6. Getting Information About Our Dataset.

# %%
# To display the structure of the dataset.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 302 entries, 0 to 878
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    int64
#  7   thalach   302 non-null    int64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    int64
#  11  ca        302 non-null    int64
#  12  thal      302 non-null    int64
#  13  target    302 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 43.5 KB

# %% [markdown]
# # Step 7. Check Null Values in the Dataset.

# %%
# To check if any null values in the Dataset.
data.isnull()
# Out:
#        age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0    False  False  False     False  False  False    False    False  False
# 1    False  False  False     False  False  False    False    False  False
# 2    False  False  False     False  False  False    False    False  False
# 3    False  False  False     False  False  False    False    False  False
# 4    False  False  False     False  False  False    False    False  False
# ..     ...    ...    ...       ...    ...    ...      ...      ...    ...
# 723  False  False  False     False  False  False    False    False  False
# 733  False  False  False     False  False  False    False    False  False
# 739  False  False  False     False  False  False    False    False  False
# 843  False  False  False     False  False  False    False    False  False
# 878  False  False  False     False  False  False    False    False  False
#
#      oldpeak  slope     ca   thal  target
# ...

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# # Step 8. Check for the DUplicate Data and Drop Them From The Dataset.

# %%
# To check if duplicates are there in the dataset.
data_dup = data.duplicated().any()
print(data_dup)
# Out:
# False

# %%
# To drop the duplicate records from the dataset.
data = data.drop_duplicates()

# %%
# To check the shape of the data after correcting the data. There are 302 rows and 14 columns in the dataset.
data.shape
# Out:
# (302, 14)

# %% [markdown]
# # Step 9. Get Overall Statistics About The Datset

# %%
# describe() method returns description of the data in the DataFrame
data.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# # Step 10. Draw a Correlation Matrix

# %%
#The corr() method calculates the relationship between each column in your data set.
data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# ...

# %%
# Display the Correlation in the form a heatmap using seaborn library.
plt.figure(figsize=(17,6))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Step 11. How many people have Heart Disease, and How many people don't Have Heart Disease in the Dataset.

# %%
# data.columns is an attribute that provides access to the column labels of a data frame
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
#The value_counts() function returns an object containing counts of unique values.
data['target'].value_counts()
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
sns.countplot(x ='target', data = data)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %% [markdown]
# # Step 12. Find the Count of Male & Females in the Dataset

# %%
# data.columns is an attribute that provides access to the column labels of a data frame
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['sex'].value_counts()
# Out:
# sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %%
sns.countplot(x ='sex', data = data)
plt.xticks([0, 1],['Female','Male'])
plt.show()
# sns.countplot(data['sex'])

# %% [markdown]
# # Step 13. Find Gender Distribution According to The Target Variable

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(x='sex',hue='target',data=data)
plt.xticks([1,0],['Male','Female'])
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
# # Step 14. Check Age Distribution in The Dataset

# %%
sns.histplot(data['age'], bins=20)
plt.show()

# %% [markdown]
# # Step 15. Check Chest Pain Type

# %%
sns.countplot(x ='cp', data = data)
plt.xticks([0,1,2,3],["typical angina","atypical angina","non-anginal pain","asymptomatic"])
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# # Step 16. Show the Chest Pain Distribution As Per Target variable

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(x='cp',hue='target',data=data)
plt.legend(labels=["No-Disease","Disease"])
plt.show()

# %% [markdown]
# # Step 17. Show Fasting Blood Sugar Distribution According To Target Variable

# %%
sns.countplot(x='fbs',hue='target',data=data)
plt.legend(labels=["No-Disease","Disease"])
plt.show()

# %% [markdown]
# # Step 18. Check Resting Blood Pressure Distribution

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['trestbps'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # Step 19. Compare Resting Blood Pressure As Per Sex Column

# %%
g = sns.FacetGrid(data, hue="sex", aspect=4)
g.map(sns.kdeplot,'trestbps',fill=True)
plt.legend(labels=["Male","Female"])
plt.show()
# Out:
# C:\Users\Sanjay\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Step 20. Show distribution of Serum Cholestrol

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['chol'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # Step 21. Plot Continuous Variables

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
cate_val=[]
cont_val=[]

for column in data.columns:
    if data[column].nunique() <=10:
        cate_val.append(column)
    else:
        cont_val.append(column)

# %%
cate_val
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
cont_val
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
data.hist(cont_val, figsize=(15,6))
plt.tight_layout()
plt.show()

# %% [markdown]
# # Step 22. Plot Categorical Variables

# %%
data.hist(cate_val, figsize=(15,6))
# plt.tight_layout()
plt.show()
